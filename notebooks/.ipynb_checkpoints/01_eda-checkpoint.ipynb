# %%
# !pip install pyLDAvis wordcloud gensim scipy
# Out:
# Requirement already satisfied: pyLDAvis in c:\users\ysass\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: wordcloud in c:\users\ysass\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: gensim in c:\users\ysass\anaconda3\lib\site-packages (4.3.2)
# Requirement already satisfied: scipy in c:\users\ysass\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy>=1.24.2 in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (3.1.4)
# Requirement already satisfied: numexpr in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (2.8.7)
# Requirement already satisfied: funcy in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: setuptools in c:\users\ysass\anaconda3\lib\site-packages (from pyLDAvis) (69.5.1)
# Requirement already satisfied: pillow in c:\users\ysass\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\ysass\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ysass\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ysass\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ysass\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ysass\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ysass\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ysass\anaconda3\lib\site-packages (from jinja2->pyLDAvis) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ysass\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ysass\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ysass\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ysass\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ysass\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ysass\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\ysass\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)

# %%
#Libraries 

import warnings; warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import nltk
import spacy

# %% [markdown]
# # STEP 1: Choosing the Database
#
# In this assignment we chose the Disneyland Review feeedback dataset. Looking at this dataset it is very clear that this is the data is broken down into 3 groups based on the locations being written about in the reviews.

# %%
#Import the dataset

disneyland_df=pd.read_csv(r"C:\Users\ysass\OneDrive\Desktop\Grad School Files\BSAN 6200 Text Mining and Social Media Analytics\text-analytics-a3-Sasson-Acosta\data\raw\DisneylandReviews.csv", header=0, encoding="latin-1")

# %%
disneyland_df
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
# [42656 rows x 6 columns]

# %%
#Documenting information about the rows and columns

#Store the number of rows in a variable
num_rows=len(disneyland_df)

#Print the clear number
print(f"There are {num_rows} in this dataset")

#2.1.2 Columns
disneyland_df.columns
#Column 1 ("Review_ID"): This column is made up of strings that are comprised of reviews
#Column 2 ("Rating"): This column is comprised of strings that either read positive or negative.
#Column 3 ("Year_Month"): This column is comprise of the date and month that the review is written in the format "YY-MM"
#Column 4 ("Reviewer_Location"): This column contains the location of the person writing the review
#Column 5 ("Review_Text"): This column contains the full reviews about the Disneyland location
#Column 6 ("Branch"): This column contains the park in which the review is written about


#2.1.3 Data Types
disneyland_df.dtypes
#Column 1 ("Review_ID"): Because this is a consistent value that cannot have mathematical operations done to it, I would classify this as a string
#Column 2 ("Rating"): This column very clearly is a numerical value that could be used in mathematical functions. This would be float.
#Column 3 ("Year_Month"): Right now it is a string, but it could be turned into a date type if we use a few functions to convert it.
#Column 4 ("Reviewer_Location"): This is a string.
#Column 5 ("Review_Text"): This is also a string.
#Column 6 ("Branch"): This is also a string. 

#2.1.4 Missing Values

#There are no missing values in this dataset.
disneyland_df.isna().sum()
# Out:
# There are 42656 in this dataset
# Review_ID            0
# Rating               0
# Year_Month           0
# Reviewer_Location    0
# Review_Text          0
# Branch               0
# dtype: int64

# %%
#2.2 Class Distribution

#Show a histogram for the distribution of the Sentiment reviews
plt.hist(disneyland_df['Branch'])
plt.xlabel("Location of Park")
plt.ylabel("Number of Reviews")
plt.title("Sentiment Distribution for Disneyland Location Review Dataset")
#Run this to save the figure as a .png file
#plt.savefig("location_distribution_hist.png")
plt.show()

#2.2.1 Is the dataset balanced?

#Shows a histogram for the length of the reviews in characters
#Finds the number of characters for each review and stores them in a variable
text_len_hist_data=disneyland_df["Review_Text"].str.len()
#Create the histogram with enough bins to show the distribution clearly
plt.hist(text_len_hist_data,bins=100)
plt.xlabel("Number of Characters in the Review")
plt.ylabel("Number of Reviews")
plt.title("Text Length Distribution for Disneyland Location Reviews")
#Run this to save the figure as a .png file
#plt.savefig("text_length_distribution_hist.png")
plt.show()

# %%
def most_popular_words(dataframe):
    words=dataframe['Review_Text'].str.split()
    all_words=words.explode()
    all_words_standard=all_words.str.lower()
    word_counts=all_words_standard.value_counts()
    top_n_words=word_counts.index[:10]
    return top_n_words

# %%
#Break Down the Different Categories
california_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_California']
hong_kong_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_HongKong']
paris_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_Paris']

print(f'The average number of characters in a review (before cleaning) is {disneyland_df['Review_Text'].str.len().mean()} characters.')
print(f'The average number of characters in a California review is {california_reviews['Review_Text'].str.len().mean()} characters.')
print(f'The average number of characters in a Paris review is {paris_reviews['Review_Text'].str.len().mean()} characters.')
print(f'The average number of characters in a Disneyland review is {hong_kong_reviews['Review_Text'].str.len().mean()} characters.')

#2.3.2 Vocabulary
#These reviews contain no emojis, more casual language, language that could be used to heighten emotion (contain emphasis). There are also certain cases where words
#are written in all caps. Depending on the person who wrote it there are some reviews that are more sopisticated in terms of word choice while other people used more 
#simple vocabulary. 

#2.3.3 Common words per class and label
print(f'The top 10 most popular words in California reviews are {', '.join(most_popular_words(california_reviews))}.')
print(f'The top 10 most popular words in Paris reviews are {', '.join(most_popular_words(paris_reviews))}.')
print(f'The top 10 most popular words in Hong Kong reviews are {', '.join(most_popular_words(hong_kong_reviews))}.')
# Out:
# The average number of characters in a review (before cleaning) is 696.8175403225806 characters.
# The average number of characters in a California review is 618.5775533340204 characters.
# The average number of characters in a Paris review is 909.370139398386 characters.
# The average number of characters in a Disneyland review is 553.4945945945946 characters.
# The top 10 most popular words in California reviews are the, and, to, a, we, of, in, was, for, i.
# The top 10 most popular words in Paris reviews are the, and, to, a, of, we, in, was, for, is.
# The top 10 most popular words in Hong Kong reviews are the, and, to, a, is, of, in, was, for, we.

# %%
print(f'The number of reviews (documents) relating to Disneyland California is {disneyland_df['Branch'].value_counts()[0]}.')
print(f'The number of reviews (documents) relating to Disneyland Paris is {disneyland_df['Branch'].value_counts()[1]}.')
print(f'The number of reviews (documents) relating to Disneyland Hong Kong is {disneyland_df['Branch'].value_counts()[2]}.')
# Out:
# The number of reviews (documents) relating to Disneyland California is 19406.
# The number of reviews (documents) relating to Disneyland Paris is 13630.
# The number of reviews (documents) relating to Disneyland Hong Kong is 9620.

# %%
from wordcloud import WordCloud, STOPWORDS

text_combined = " ".join(california_reviews['Review_Text'].dropna().str.lower())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)

plt.figure(figsize=(10, 8))
plt.title('California Disneyland Initial Word Cloud (Before Cleaning)')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text_combined = " ".join(paris_reviews['Review_Text'].dropna().str.lower())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)

plt.figure(figsize=(10, 8))
plt.title('Paris Disneyland Initial Word Cloud (Before Cleaning)')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text_combined = " ".join(hong_kong_reviews['Review_Text'].dropna().str.lower())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)

plt.figure(figsize=(10, 8))
plt.title('Hong Kong Disneyland Initial Word Cloud (Before Cleaning)')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Vocabulary for each group
text_combined_hong_kong = " ".join(hong_kong_reviews['Review_Text'].dropna().str.lower())
text_combined_paris = " ".join(paris_reviews['Review_Text'].dropna().str.lower())
text_combined_california = " ".join(california_reviews['Review_Text'].dropna().str.lower())

individual_words_hong_kong=text_combined_hong_kong.split()
individual_words_paris=text_combined_paris.split()
individual_words_california=text_combined_california.split()


# Get the unique words (vocabulary) using a set
vocabulary_hong_kong = set(individual_words_hong_kong)
vocabulary_paris = set(individual_words_paris)
vocabulary_california = set(individual_words_california)


print("Vocabulary Hong Kong:", vocabulary_hong_kong, '\n')
print("Vocabulary Paris:", vocabulary_paris, '\n')
print("Vocabulary California:", vocabulary_california, '\n')
# Out:
# Vocabulary Hong Kong: {'age..', 'weekends.', 'activities,', 'spatula,', 'arent', 'drumstick', 'times)', 'saber', 'childrens', 'merely', 'unnecessarily.', 'tagged', 'them,but', 'biggest,', 'eggette,', 'result.', 'same...more', '6a', 'overseas)', 'shuttles.', 'toes,', 'figure!!', 'lands.to', 'disappeared.', 'toilet,', 'fantasyland)', '...jokes', 'fantasylandafter', 'hassle.', 'mesmerizing.the', 'thrilling)mystic', 'consideration.', 'royces.', 'kids...teenagers', 'shoes!', 'kababayans,', 'panicking', 'other.', 'nook', 'dumbo', 'carriages,', 'little.the', 'express', 'tinkerbell,', 'one.my', 'minne', 'yeas', 'host', 'try:1.', 'reviews', 'ignore', 'rivals', 'sep.', '09:20', 'fun.my', 'those!toy', 'deal', 'occasionally', 'skies', 'chui.', 'brochures,', 'attractions.infants', 'walking,', 'day!!1', 'bored.', 'helpfully', 'good....good', 'server', 'ones.heading', 'increases', 'say)', 'forgot!', 'stand', 'quick,', 'country', 'studio).', 'doubt,', 'castle?', '7yo,', 'cultures', 'costly.', 'reducing', '6', 'worthwhile.', 'vary', '60usd', "prices'.", '$538', 'parks.my', "paris(i've", 'plentiful,', 'puller', 'shortest,', 'frankly,', 'octopus.', 'afternoons', 'kept.', 'hkd$470', 'brand.', 'hkd!!!!', '530hkd', 'fanta.', 'definitaley', "'it", '?in', 'cheerful!', 'fantastic.7.', 'ride....its', 'mtr.travelling', 'sings', 'madness:', 'profoundly', 'conviction', 'worked.', 'location.the', 'unselfish', 'appropriate.the', 'so.strollers', 'crowds!', 'brazenly', '(instead,', 'nonetheless.6)', 'mesmerising.', 'disability', 'dewgon', '(27', '74', 'are.you', 'saturated.', 'parks.also', "mouse'", 'very2', 'lunchall', 'toycar,', '(firing', 'food:huge', 'out...but', 'constantly', 'programme', 'misses,', 'function.i', 'belt,', 'thoroughly.our', 'seeker.rides', 'december!!the', 'tasty!', 'park.if', 'lower.the', 'daughter', 'less.', 'that)', 'fizzy', "'amazing'", 'mountian', 'moved', 'breads,', 'complaints,', 'monopod:', 'a9f0', 'potter),', '400', 'consistency.', 'tommorland.', 'fast.when', 'buster.', 'her', 'parade,fireworks,', 'swag.', 'rides.3)', 'tiredness.key', 'ever.i', 'ideally', 'catering', 'fansi', '104', 'overawed', 'sweating', 'protection.', 'hkd$100', '(king', 'starwars', ':)i', 'money.3.', 'cantonese.tips:highlights', 'threat', 'moana)', 'spaces.', 'permitted.', 'feelings', 'eight', 'disrupt', 'displays.', '(magic', 'elderlys,', 'floridian.', 'chicken', 'redeemable', 'quarters,', '1:30,', 'mines.', 'octypus', 'spoken', 'again...absolutely', '(60hkd', 'harley!well', 'shape', 'hippos,', 'cleanliness', 'family.incident', 'didn`t', 'wouldn`t', '$515', 'tomorrowland,', 'enthusiasts', 'hills!', 'crispy', 'shorted', '(marvel', 'nappy', '$1000', 'definity', 'chested.', 'dizzy.', 'slim', 'jurassic', '16th,', 'weathet.', 'already!', 'gbp.free', 'stocked', 'online...no', 'joyful.', 'elaborate.', 'attraction...more', 'changedthere', 'potty', '1', 'saw.the', 'rainless', 'trudged', 'dislikes:', '67', 'enjoyment.', 'queue.use', 'old!),', 'making', 'displeased', 'poisition', 'trees.', 'feel.', '(also', 'miscalculations,', 'go)', 'danced.we', 'sauce).', 'memories....excellent', '48', 'experience!!', 'a21', 'extends.i', '(space', 'prepaid.', 'sg', 'efficiently.', 'shoot.', '$150,', 'felt)', 'hydrate', 'better..', 'showtime.here', 'uncles', 'expensive).it', 'chilhood', 'straightforward', 'pass).', 'most', 'handy,', 'blocking.', 'partners', 'wandered', 'name.', 'place..they', 'revisions', 'hollywood,', 'enyoy', 'everlasting', 'translation', 'kong,china.', 'well.every', 'umbrella(in', 'challenged', 'tommorowland,', 'too.never', 'slaying', '(10:15am)', '$nz25', 'storytellers', '(these', 'evenly', ":)i'd", 'could!for', 'enough', 'place.we', 'bad....', 'aircon.', 'seeking,', 'china!there', 'hollered', 'persist', 'vaunted', 'baby,which', 'centred', 'keepers', 'funand', 'relished', 'then!', 'toll...', '(obviously', 'warned.', 'new', 'begin,', 'hk$90', 'entertaint', 'entrancecharacters', 'bros', 'mermaid', 'summer.every', 'dayviewpagewe', '(bus', 'show.there', 'hadn', 'true! ...
#
# Vocabulary Paris: {'crowdy)', 'oversell', 'parks,disneyland', 'summary:', 'studies', 'kindle', 'cinderella!', "arthur's", 'september...hardly', 'weekends.', 'activities,', 'diet.the', 'arent', 'quiet.you', 'drumstick', 'horible', 'nearer!!', 'times)', 'saber', 'parks,disney', 'occupied!!7', 'downtime,', 'lost!', 'jaded?', '(celsius)', 'childrens', 'merely', 'euro...)', 'solid.', 'view.it', 'tagged', 'them,but', 'biggest,', 'from.the', 'disney)*fast', 'orlando.we', 'writing.the', 'chistmas', 'result.', "daughter.'it's", 'pan...it', 'refined', 'shuttles.', 'working?all', 'disappeared.', 'toilet,', "upgrade'.", 'fantasyland)', '2013we', 'florida.this', 'ride!.', 'shear', 'lichter', 'shyness', 'neat,just', 'hassle.', 'efficiency).', 'lamer.', 'stores!', 'spectacualr.i', 'thill', 'downloadedthe', '10am..although', 'lancashire', 'firewoks,', 'on!if', 'castle...that', 'consideration.', 'more.a', 'convient', '1.02mflying', 'thomson', 'seemed.', '.....rides', 'shoes!', 'you.next', 'cafe.....and', 'reforms', 'panicking', 'other.', 'nook', 'before!i', '7.40', 'dumbo', 'trip.two', 'carriages,', "here,it's", 'little.the', 'rhinitis', 'dinnertime!', 'predicted.still', 'express', '(5pm),', 'tinkerbell,', 'one.my', 'minne', 'extra!!!', 'host', 'systems;', 'people.last', 'reviews', 'ignore', 'rivals', 'check)', 'seats.the', '09:20', 'greet)all', 'greetswe', 'fun.my', 'cigars!),', 'agrabah.', 'ireland)', 'deal', 'occasionally', 'skies', 'shop!!', 'dealings', 'faired', 'sipped', 'definitivamente', 'arrived!', 'drainage.', 'having.', 'brochures,', 'fun!),', 'walking,', 'bored.', 'helpfully', 'server', 'hustle!otherwise', 'increases', 'casino', 'live.you', 'trapped!', 'want....', 'say)', 'cuckoo', 'shoe!if', 'forgot!', 'stand', 'country', 'quick,', 'cheyenne.to', 'highlight!!', 'doubt,', 'castle?', 'cultures', 'price4)', 'relative!', 'refreshements', 'meh....', 'bailing', 'country...,', 'stunner!', 'amusement.the', '2017,but', '120euro,', '4g', 'trudge', 'category)', 'brilliant),', 'costly.', 'reducing', 'thermoplastic', "cost.can't", 'that!4', '6', 'difference.see', 'worthwhile.', 'vary', 'rubbish.i', 'stich.', 'car,via', 'montian,', 'better!),', 'parks.my', 'day....after', 'lad..', '22.also', 'mathematically', 'plentiful,', 'work.specificaly,', 'villiage', 'characters!i', 'overworked.', 'way:1', 'downhill.biggest', 'halloween!?the', 'we.found', 'frankly,', '7.45am.', ':)one', 'important.journey', 'dnagerous', 'heaters.', 'but...we', 'usuals', 'afternoons', 'kept.', 'ludicrous.when', 'puzzles', 'brand.', 'children!!!', 'bedroom.', 'fanta.', 'photopass.', 'occurrence,', 'espiecally', 'frenetic.', "amazing.don't", '(badly)', 'characters.as', 'carbonated', 'action.140', 'chatty,', 'hols', "'it", 'greet.a', 'fantatsic', '(cut', "accurate.there's", 'trip.adventureland', 'excepted)', 'sings', 'lg', 'vocuhers', 'ranch.the', 'equip', 'charachter!', 'railway.', '20:40', 'profoundly', '3rides,', 'many.overpriced', 'worked.', 'stone,', 'stunningly', 'trains.done.', 'adultsfood', 'crowds!', 'parks.at', 'areas.parade', '(awesome!)', 'brazenly', 'entrance!concluding:', 'mesmerising.', 'result?', 'ratatouille!!)', 'disability', "might've", 'quoi', '74', 'slow.frankly', 'centre)alot', 'much.there', "mouse'", 'deligtht,', 'aggravated.', 'cradle', 'said!', "'indiana", 'keyrinf', 'one.studios', 'easiertickets', "'heroes',", '5,8', 'flybe', 'cutoff', 'unnoticed', 'satyrday', '2...4d', 'awful.the', 'constantly', 'simple....thank', 'programme', 'cares.the', 'nice.recommended', 'negatives.the', 'enlightening.', 'visits!disney', 'pelasure', 'longest).', 'girl...', 'belt,', 'martin', '(wow!)*stich', 'tasty!', 'goodneeds', 'park.if', 'smoking.a', 'daughter', 'fizzy', 'less.', 'that)', 'samey', 'mostif', 'toa', 'efficient!', 'mountian', 'clever).', 'moved', 'breads,', ')2.', 'complaints,', '400', 'peruse', 'pass.only', 'consistency.', 'refills,', 'her', "floor.it's", 'universal.points', 'rpint', 'it.okay,', 'diy,', 'euro.here', 'rides.3)', 'variant.so', 'special.firstly',  ...
#
# Vocabulary California: {'parks,disneyland', 'oversell', 'mad.we', 'summary:', 'breakfast,get', 'lineas', 'sylmar', 'age..', "arthur's", 'cinderella!', 'parks...our', 'kindle', 'weekends.', 'activities,', 'law;', 'arent', 'drumstick', 'home.get', 'whining...bring', '2006)', 'times)', 'institutional', 'radiater', 'saber', 'fearful', 'parks,disney', 'be!)', 'endured;', 'dressings.', 'christine', 'that.later', "nowadays,it's", 'done...food', 'anyway)*', 'lost!', '(celsius)', 'childrens', 'merely', 'needed..', 'solid.', 'unnecessarily.', 'tagged', 'from.the', 'orlando.we', 'chistmas', 'result.', 'distributions.', 'shuttles.', 'toes,', 'here).our', 'refined', 'madagascar???because', 'disappeared.', 'too.staff', 'toilet,', 'fantasyland)', 'days.have', 'deserted.8.', 'trash!', 'february...but', 'drem', 'shear', 'cobra', 'skyschool,', 'hassle.', 'splashdown,', 'scrutiny', 'stores!', 'thill', 'amazeballs.', 'opening.3.', 'fantastic...not', 'castle...that', 'consideration.', 'more.a', 'convient', 'following:been', 'cups!enjoy!', 'seemed.', 'shoes!', 'panicking', 'dhh', 'other.', 'nook', 'different.)', 'sacto', 'dumbo', 'carriages,', 'little.the', 'unstuffed', 'express', 'tinkerbell,', 'yeas', 'error)called', 'minne', 'host', 'eventsfrozen,', 'ate;', 'peek!', 'reviews', 'ridemax!!!', 'ignore', 'rivals', "'higher", 'check)', 'info.food', 'employees..', 'enjoyment!', 'fun.my', 'deal', 'occasionally', 'pilgrimages', 'skies', '(card).3.grab', 'dealings', 'cocacola', 'having.', 'miraculous', 'impressionable', 'here...but', 'fun!),', 'walking,', 'esplanade.', 'bored.', 'helpfully', 'server', '630p,', 'ropeway', 'increases', 'detail.fast', 'casino', 'squishy.', 'cuckoo', 'tommorowland!', 'polynesian)', 'apple.indiana', 'hike).', 'stand', 'country', 'quick,', 'nightmare...you', 'pros,', 'those)', 'bailing', 'highlight!!', 'doubt,', 'cultures', 'castle?', 'entry...here', 'times).one', 'meh....', 'performance.although', 'restore,', 'rest.everything', 'california.we', 'i.e.:', 'too.enter', 'costly.', 'reducing', '6', 'worthwhile.', 'vary', 'yourself.definite', 'parks.my', 'yellowish', 'tehy', 'byte', 'solicitation', 'awesome!most', 'plentiful,', 'kingdoms!', 'overworked.', 'frankly,', 'shortest,', 'ask?!!!', 'heaters.', 'shuttle..beware', "holder's", 'crawling).', 'afternoons', 'kept.', 'but...we', 'deeper.', 'parks.anyway', 'brand.', 'peacefull', 'bedroom.', 'photopass.', 'joyful,place.', 'hi,on', 'gelato,', 'frenetic.', "'it", 'hols', 'boatsthe', 'woc', 'chatty,', 'anxieties.', 'toe.', 'line.3)', 'hotcakes', 'sings', 'break!)', 'madness:', '50s.unless', 'rain....if', 'railway.', 'intoxicated', 'worked.', 'stone,', 'lol!all', 'stunningly', 'issued.matterhorn', 'adultsfood', 'crowds!', 'mesmerising.', 'mover...over', 'disability', 'great,,the', 'x2!', 'quoi', "might've", '74', 'saturated.', "mouse'", 'attractions....so', 'app....it', 'said!', 'parker).', 'cutoff', 'citi', 'endangered', 'constantly', 'success!', 'programme', 'slow...building', '$87,', 'martin', 'girl...', '40ish', "stations',", 'josiah', '(howard', 'tasty!', 'hours.corporate', 'run.9', 'to.both', 'park.if', "too.i've", 'less.', 'daughter', 'that)', 'kidfriendly', 'expensive.........', 'forehead', 'agin,', '(2008)', 'mountian', 'moved', 'complaints,', 'planet.everything', '400', 'peruse', 'consistency.', 'robe', 'refills,', 'her', 'it,.....dont', 'maxpass!', '($10', 'califronia', 'breakfast.a', '1989', 'ciaos.', 'ever.i', 'cost.disneyland', 'ideally', 'minutes....we', 'procedures.', 'for,jedi', 'appr', 'favorably', 'catering', '104', 'overawed', 'sweating', 'it!overall', 'squealing', 'lonnnnngggggg', '(king', '(touch', 'purists', '$19', 'amanda', 'age.along', 'hesitate.....you', 'all!thanks,', 'starwars', ':)i', 'itemized', 'threat', 'i!i', 'familer', 'studios0', 'money.3.', 'macho', 'see!),', 'harshness', 'known.', 'rewarding...seeing', 'permitted.', '(under5)', 'spaces.', 'feelings', 'eight', 'treasure!i', 'displays.', 'tropicana', 'common??', '(launch', '(magic', 'clarion', '(w.',  ...

# %%
# Store the dataframe variable so we can use it in the exact same state in the next notebook
# %store disneyland_df
# Out:
# Stored 'disneyland_df' (DataFrame)
