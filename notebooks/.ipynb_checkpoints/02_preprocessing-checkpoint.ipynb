# %%
#Libraries 

import warnings; warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
import nltk
import spacy
# Text processing
import re
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import contractions

# %%
#Retrieve the dataset without having to import the dataset again

# %store -r disneyland_df

# %%
disneyland_df
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
#                                           review_cleaned  \
# 0      If you have ever been to Disneyland anywhere y...
# 1      Its been a while since d last time we visit HK...
# 2      Thanks God it wasn t too hot or too humid when...
# 3      HK Disneyland is a great compact park. Unfortu...
# 4      the location is not in the city  took around 1...
# ...                                                  ...
# 42651  i went to disneyland paris in july 03 and thou...
# 42652  2 adults and 1 child of 11 visited Disneyland ...
# 42653  My eleven year old daughter and myself went to...
# 42654  This hotel  part of the Disneyland Paris compl...
# 42655  I went to the Disneyparis resort  in 1996  wit...
#
#                                clean_review_wo_stopwords  \
# 0      ever anywhere find Hong Kong similar layout wa...
# 1      since last visit HK .. Yet, stay Tomorrowland ...
# 2      Thanks God hot humid visiting otherwise would ...
# 3      HK great compact park. Unfortunately quite bit...
# 4      location city, took around 1 hour Kowlon, kids...
# ...                                                  ...
# 42651  paris july 03 thought brilliant. visited hotel...
# 42652  2 adults 1 child 11 visited Paris beginning Fe...
# 42653  eleven year old daughter visit son London deci...
# 42654  hotel, part Paris complex, wonderful place fam...
# 42655  Disneyparis resort, 1996, small child. minute ...
#
#                       clean_review_wo_stopwords_and_punc
# 0      ever anywhere find Hong Kong similar layout wa...
# 1      since last visit HK .. Yet  stay Tomorrowland ...
# 2      Thanks God hot humid visiting otherwise would ...
# 3      HK great compact park. Unfortunately quite bit...
# 4      location city  took around 1 hour Kowlon  kids...
# ...                                                  ...
# 42651  paris july 03 thought brilliant. visited hotel...
# 42652  2 adults 1 child 11 visited Paris beginning Fe...
# 42653  eleven year old daughter visit son London deci...
# 42654  hotel  part Paris complex  wonderful place fam...
# 42655  Disneyparis resort  1996  small child. minute ...
#
# [42656 rows x 9 columns]

# %%
def clean_text_total(text):
    """
    Clean raw text by removing noise.
    
    Steps:
        1. Remove HTML tags (e.g., <p>, <div>, <br>)
        2. Remove URLs (http://, https://, www.)
        3. Remove email addresses
        4. Normalize whitespace (multiple spaces → single space)
    
    Parameters:
        text (str): Raw text string
    
    Returns:
        str: Cleaned text string
    
    Example:
        >>> clean_text("<p>Visit http://example.com or email test@mail.com</p>")
        'Visit or email'
    """
    # Handle missing values
    if pd.isna(text):
        return ""
    
    # Convert to string
    text = str(text)
    
    # Step 1: Remove HTML tags
    # Pattern: <anything> where anything doesn't contain >
    text = re.sub(r'<[^>]+>', '', text)
    
    # Step 2: Remove URLs
    # Pattern: http(s):// or www. followed by non-whitespace
    text = re.sub(r'http\S+|www\.\S+', '', text)
    
    # Step 3: Remove email addresses
    # Pattern: something@something.something
    text = re.sub(r'\S+@\S+', '', text)

    #Step 4: Catch any additional HTML that didn't make it through the initial cleaning steps.
    text= BeautifulSoup(text, "html.parser").get_text()
    
    # Step 4: Normalize whitespace
    # Replace multiple spaces/tabs/newlines with single space
    text = re.sub(r'\s+', ' ', text).strip()

    # Step 5: Expand contractions
    text=contractions.fix(text)

    #Removes Special Characters
    text=re.sub(r'[^a-zA-Z0-9. !?]', ' ', text)

    #Removes Punctuation which isn't necessary for topic modeling
    text=re.sub(r'[^a-zA-Z0-9 ]', ' ', text)
    
    return text

# %%
disneyland_df['review_cleaned']=disneyland_df['Review_Text'].apply(clean_text_total)

# %%
nltk.download('stopwords') #need to download this pre-trained data for using with word tokenizer
#
stop_words_nltk = list(stopwords.words('english')) #define English as the stop words

#Create a new column to store the cleaned text
disneyland_df['clean_review_wo_stopwords']=disneyland_df['review_cleaned'].copy()

#Go through each review and remove any stopwords that exist.
for review in range(0, len(disneyland_df)):
    a = disneyland_df.Review_Text[review].split()
    sentence=[ x for x in a  if x.casefold() not in stop_words_nltk]
    disneyland_df['clean_review_wo_stopwords'][review]=" ".join(sentence)

custom_stopwords = ['disneyland','disney','park','day','time','went','also','really','just']

for review in range(0, len(disneyland_df)):
    a = disneyland_df.clean_review_wo_stopwords[review].split()
    sentence=[ x for x in a  if x.casefold() not in custom_stopwords]
    disneyland_df['clean_review_wo_stopwords'][review]=" ".join(sentence)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ysass\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
disneyland_df
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch  \
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2      Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3      HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4      the location is not in the city, took around 1...  Disneyland_HongKong
# ...                                                  ...                  ...
# 42651  i went to disneyland paris in july 03 and thou...     Disneyland_Paris
# 42652  2 adults and 1 child of 11 visited Disneyland ...     Disneyland_Paris
# 42653  My eleven year old daughter and myself went to...     Disneyland_Paris
# 42654  This hotel, part of the Disneyland Paris compl...     Disneyland_Paris
# 42655  I went to the Disneyparis resort, in 1996, wit...     Disneyland_Paris
#
#                                           review_cleaned  \
# 0      If you have ever been to Disneyland anywhere y...
# 1      Its been a while since d last time we visit HK...
# 2      Thanks God it wasn t too hot or too humid when...
# 3      HK Disneyland is a great compact park  Unfortu...
# 4      the location is not in the city  took around 1...
# ...                                                  ...
# 42651  i went to disneyland paris in july 03 and thou...
# 42652  2 adults and 1 child of 11 visited Disneyland ...
# 42653  My eleven year old daughter and myself went to...
# 42654  This hotel  part of the Disneyland Paris compl...
# 42655  I went to the Disneyparis resort  in 1996  wit...
#
#                                clean_review_wo_stopwords  \
# 0      ever anywhere find Hong Kong similar layout wa...
# 1      since last visit HK .. Yet, stay Tomorrowland ...
# 2      Thanks God hot humid visiting otherwise would ...
# 3      HK great compact park. Unfortunately quite bit...
# 4      location city, took around 1 hour Kowlon, kids...
# ...                                                  ...
# 42651  paris july 03 thought brilliant. visited hotel...
# 42652  2 adults 1 child 11 visited Paris beginning Fe...
# 42653  eleven year old daughter visit son London deci...
# 42654  hotel, part Paris complex, wonderful place fam...
# 42655  Disneyparis resort, 1996, small child. minute ...
#
#                       clean_review_wo_stopwords_and_punc
# 0      ever anywhere find Hong Kong similar layout wa...
# 1      since last visit HK .. Yet  stay Tomorrowland ...
# 2      Thanks God hot humid visiting otherwise would ...
# 3      HK great compact park. Unfortunately quite bit...
# 4      location city  took around 1 hour Kowlon  kids...
# ...                                                  ...
# 42651  paris july 03 thought brilliant. visited hotel...
# 42652  2 adults 1 child 11 visited Paris beginning Fe...
# 42653  eleven year old daughter visit son London deci...
# 42654  hotel  part Paris complex  wonderful place fam...
# 42655  Disneyparis resort  1996  small child. minute ...
#
# [42656 rows x 9 columns]

# %%
#Break Down the Different Categories
california_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_California']
hong_kong_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_HongKong']
paris_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_Paris']

from wordcloud import WordCloud, STOPWORDS

text_combined = " ".join(california_reviews['clean_review_wo_stopwords'].dropna().str.lower())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)

plt.figure(figsize=(10, 8))
plt.title('California Disneyland Initial Word Cloud (After Cleaning)')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text_combined = " ".join(paris_reviews['clean_review_wo_stopwords'].dropna().str.lower())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)

plt.figure(figsize=(10, 8))
plt.title('Paris Disneyland Initial Word Cloud (After Cleaning)')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text_combined = " ".join(hong_kong_reviews['clean_review_wo_stopwords'].dropna().str.lower())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_combined)

plt.figure(figsize=(10, 8))
plt.title('Hong Kong Disneyland Initial Word Cloud (After Cleaning)')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
def most_popular_words(dataframe):
    words=dataframe['clean_review_wo_stopwords'].str.split()
    all_words=words.explode()
    all_words_standard=all_words.str.lower()
    word_counts=all_words_standard.value_counts()
    top_n_words=word_counts.index[:10]
    return top_n_words

# %%
california_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_California']
hong_kong_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_HongKong']
paris_reviews=disneyland_df[disneyland_df['Branch']=='Disneyland_Paris']

print(f'The average number of characters in a review (after cleaning) is {disneyland_df['clean_review_wo_stopwords'].str.len().mean()} characters.')
print(f'The average number of characters in a California review (after cleaning) is {california_reviews['clean_review_wo_stopwords'].str.len().mean()} characters.')
print(f'The average number of characters in a Paris review (after cleaning) is {paris_reviews['clean_review_wo_stopwords'].str.len().mean()} characters.')
print(f'The average number of characters in a Disneyland review (after cleaning) is {hong_kong_reviews['clean_review_wo_stopwords'].str.len().mean()} characters.')

#2.3.2 Vocabulary
#These reviews contain no emojis, more casual language, language that could be used to heighten emotion (contain emphasis). There are also certain cases where words
#are written in all caps. Depending on the person who wrote it there are some reviews that are more sopisticated in terms of word choice while other people used more 
#simple vocabulary. 

#2.3.3 Common words per class and label
print(f'The top 10 most popular words in California reviews (after cleaning) are {', '.join(most_popular_words(california_reviews))}.')
print(f'The top 10 most popular words in Paris reviews (after cleaning) are {', '.join(most_popular_words(paris_reviews))}.')
print(f'The top 10 most popular words in Hong Kong (after cleaning) reviews are {', '.join(most_popular_words(hong_kong_reviews))}.')
# Out:
# The average number of characters in a review (after cleaning) is 431.51045573893475 characters.
# The average number of characters in a California review (after cleaning) is 382.17139029166236 characters.
# The average number of characters in a Paris review (after cleaning) is 563.3518708730741 characters.
# The average number of characters in a Disneyland review (after cleaning) is 344.24178794178795 characters.
# The top 10 most popular words in California reviews (after cleaning) are get, rides, go, one, ride, great, would, fast, place, like.
# The top 10 most popular words in Paris reviews (after cleaning) are rides, get, one, go, would, food, good, great, ride, paris.
# The top 10 most popular words in Hong Kong (after cleaning) reviews are rides, one, hong, get, go, kids, food, great, place, kong.

# %%
# Vocabulary for each group
text_combined_hong_kong = " ".join(hong_kong_reviews['clean_review_wo_stopwords'].dropna().str.lower())
text_combined_paris = " ".join(paris_reviews['clean_review_wo_stopwords'].dropna().str.lower())
text_combined_california = " ".join(california_reviews['clean_review_wo_stopwords'].dropna().str.lower())

individual_words_hong_kong=text_combined_hong_kong.split()
individual_words_paris=text_combined_paris.split()
individual_words_california=text_combined_california.split()


# Get the unique words (vocabulary) using a set
vocabulary_hong_kong = set(individual_words_hong_kong)
vocabulary_paris = set(individual_words_paris)
vocabulary_california = set(individual_words_california)


print("Vocabulary Hong Kong:", vocabulary_hong_kong, '\n')
print("Vocabulary Paris:", vocabulary_paris, '\n')
print("Vocabulary California:", vocabulary_california, '\n')
# Out:
# Vocabulary Hong Kong: {'windows...', 'facts', 'adult.travelling:', 'pretence', 'treehouse).', 'friend', "malaysia's", 'ride.park', 'evident,', 'believing,', 'miniscule', 'grateful', 'homes', 'unimaginative', 'taste.', 'average,', 'breakfast,', '112', 'minnies).', 'jostled', 'smiling', 'muslim,', 'coat', 'more.the', 'helpful', 'friends?', '9th).like', 'quiet!', 'combined.', 'foundtains:', 'crossed', 'sunset,', 'updating.a', 'halloween!', 'budget', '(nobody', 'hkd1000.', '57%', 'complains', 'express..', 'chilkdren.', 'powerbanks', 'properties.getting', 'merriest', '(sentimental', '$168cheese', 'park!', 'following', 'blasters', 'oar', 'prediction.', '(10am)', 'drink:', 'hkd100', 'scenary', 'entertaintment', ')however', 'hahah.', 'reasons,', 'kindniss', '1030', 'synonomous', 'absorbed', 'see)', 'weather),', 'bored', 'same..thanx', 'mytic', 'youself.', 'afterwards.4.', 'practical', 'dvds', 'placards', 'day!an', 'here:https:', 'of...more', 'cafes', 'noise.', 'disneyland!!!', 'factor,', "person's", 'wife,', '(weather', 'feared.', '40minutes', 'college', 'him.', 'woods', 'disneyland..pick', 'stated,', 'dismay', 'circle.', 'amazing.very', 'difference.this', 'fireworks!sleeping', 'work,', 'toystoryland,', 'fantastic,having', 'dint', 'roll8.', 'steep.', 'eating!', 'theirchildren.save', 'both!!!', 'midterm', 'opera', 'it.disneyland', 'detracts', 'def', 'attractive!', 'scourge.', 'hotel;', '112cm,', 'experienced:1.', 'limit', 'there.hong', 'emergence', 'sight,', 'watching.', 'visited),', 'situation.', 'treat,', 'sides,', 'rough', '3d,4d', 'wondorous', 'blowing.the', 'on..the', 'fav', 'princesses)', 'hakuna', 'pants,', "carriage).it's", 'place.there', 'takes,', '(10.30', 'consequence,', 'lifetime!!!', 'wige', 'wrapped', 'facade', 'crab', 'more.many', 'gulch)', 'serves.', 'yet.', 'available,', 'options.', 'nephews', 'passed,', 'here.', '31,2018.', 'rekindled', 'place...can', 'hi', "'one", 'virture', 'boring...', 'design', 'tht', 'fun;', 'would', 'photographs.', '8pm)', 'saturday.lines', '2008...there', 'tolong', 'servings.', 'did.', 'greenary', 'beautifully,', 'kong.first', 'good!!', 'rides,even', 'chicken.', 'etc.the', 'budge', 'exit', 'separately).', 'pass)3)', 'size!!', 'showtoystory', 'halo', '...that', 'day.besides', 'raining!', 'year..', 'central', 'yearswhen', 'disappoint', 'extreamly', '415', 'oriental', '3km', 'closed.3.', 'investment).', 'exuded', '(simple', 'gel', 'hats,', 'program', '11years', 'use', '8:30pm', 'weekends.11)', 'kids!tomorrowlandlast', 'hooot.', 'life.', '(been', ')~exact', 'ts', "tokyo's", 'putonghua)', 'singing)..', 'that.souvenir', 'tokyo.', 'mountain,4', 'manor...i', 'creeps', 'products', 'is.on', 'disappointing.my', 'tommorland.', 'handlebars.', 'trees!if', 'weekend', 'hardly', '(faster', 'line)lai', 'ie', 'eurodisney!', 'rain)', '60hkd', 'possessed', 'command.', 'safe.overall,', 'timing.', 'two)', '9pm.....children', 'vist', 'smoothly', 'mountains),', 'mini!', 'iaapa', '12mins,really', 'convenient.the', 'versa.', 'weddings...', 'china,', 'cool!!!', 'already.for', 'wire', 'gateway,walked', 'lad.disneys', 'sweet', 'center,', 'tossed', 'junky,', 'longer,', '...no', 'disappoint,', 'gizzly,', 'elsewhere?there', 'endeed', 'parks.what', 'attentions', 'inherent', 'grueling', 'authentic!', 'affordable', '149', '9:00', 'aussies!!', 'shame).', 'closed!!', 'combos', 'obvious.', 'webs', 'promising', 'nature,', 'temperature.', 'careless.', 'sumptuous', 'girl.', 'puppets,', 'etiquette', 'theme!one', 'forgiving', '(mandarin', 'sort', 'ferari', '900', 'good...clear', 'fiend', 'ones.', 'miniature,', 'beholding', 'toooo', 'tomorrowland,', 'right?', 'conditioned..or', 'kl?', 'diversion.', 'rate).', '(line', 'closure,', 'marvelous', 'keen.', 'adults,', 'pilhar', 'criteria', 'conking', 'feeling......', '3hrs.', 'urinating', 'swim.', 'soup', 'boring.weather', 'not.i', 'selling)', "march'10,", 'childhood.to', 'free!', 'windows.plus', 'max)', 'absolutely', 'executed,', 'collector,', 'area.disneyland', 'rip', 'horsey', 'point).the', ' ...
#
# Vocabulary Paris: {'laser.', 'facts', 'organisor,', 'm.j.', '20s)', 'maneck', 'outstanding.the', 'exhausting!..we', 'permission', 'relocate', 'pretence', 'out.would', 'ridelook', 'freak.', 'itself..waiting', '!disney', 'friend', 'itself)', 'eurodisney).', '3day', 'evident,', 'miniscule', 'grateful', 'evening.so', 'homes', '1euro.*', 'exchage', '1:00?', 'unimaginative', 'taste.', 'times;', '9year', 'breakfast,', 'slushing', 'chicken?', 'average,', '%30', 'whinging,', 'legal', 'adds,verry', 'downfalls,', "but.......there's", 'jostled', 'smiling', 'muslim,', 'coat', 'more.the', 'emery', 'olaf!!!!', 'rudely,', '(recovering', 'upkeepwent', 'helpful', 'rigid.', "mae's", 'uplifting!', 'installed,', "'saloon", 'decorum,', "'jobsworth'.", 'originals.', 'quiet!', 'better.cant', 'picturesque,', 'blooming', 'combined.', 'gouvernment', 'morning.was', '(160z', 'ravenous', 'crossed', 'sunset,', 'way.two', 'open,even', 'halloween!', 'mickey.we', '8.15,', 'bunny', 'budget', 'tbat', 'personalities......specifically', 'asd', 'sugared', "refurbishment'", 'feeling.unlike', 'complains', 'paris,and', '94.', 'faultless!', 'restaurants.not', 'them?!!!!', 'attraction.so', 'situations.the', 'flied', '3pm.sadly', 'park!', 'makers', 'following', 'know.event', 'blasters', 'friday!!', '75,', '2.1', 'brilliant.yes', 'unloaded', 'nugget,eat', 'drink:', '(10am)', 'scenary', 'paris!first', 'story!', 'later.we', 'entertaintment', 'soooo..', 'everytime,i', '9:20.', 'hype.it', 'animagique,', '2am,', 'youtu.be', '40mins...so', 'opened;2.', 'entry..', 'christoff', '27euro!!', 'reasons,', '1030', 'absorbed', 'see)', 'bored', 'you.remember', 'thrill;', 'first...my', 'skepitcal', 'practical', 'dvds', 'going!would', 'time(when', 'rides,had', 'december!', 'cafes', 'awesome.visited', 'disneyland!!!', 'checked)', 'uninterested).', 'factor,', 'laserpointers,', 'park!,', 'world,you', 'atleast.', 'misery', "person's", '5*queue', 'it.main', 'wife,', 'kids.characters:our', 'room),', '(weather', 'feared.', '40minutes', 'college', 'attire,', 'him.', 'day).waited', 'hairdrier', 'ige,', 'angst', 'some),', 'place,all', 'woods', 'perfectly.the', 'stated,', 'dismay', 'disgusting!overall', 'tv;', 'autographs.in', 'circle.', 'work,', 'eur', 'rates,', 'yikes!!', 'steering', 'mountain...closedwent', "1'", 'parade.....food', 'dint', 'steady.costseurope', 'steep.', 'detours', 'respected', 'eating!', 'had.highlights', 'princess!if', 'berny', 'faces.a', 'rainforest,', 'opera', 'solidified', 'month.disneyland', 'it.disneyland', "'goose", 'shows!!already', 'rapunzel!', 'snacks).', 'ordered?', '(sigh)..', 'dungeons!the', 'niggles.', 'moteurs', 'detracts', 'def', 'exit.keep', 'generic.', '11:50', 'flight.a', 'individually.', 'hotel;', 'ones!we', 'vinegarette', 'waisting', 'limit', 'early!.', 'happy.the', 'improvise', 'experienced.4)', 'mediocre)$$', 'sight,', 'watching.', 'situation.', 'crowds.usual', 'eurosdisney', 'treat,', 'sides,', 'help.some', 'meteor', 'rough', 'anther', 'options.its', 'beign', 'confused).', 'fav', 'princesses)', 'hakuna', 'desk.if', 'muscling', 'mask,', 'parkside', 'arms,', 'place.there', 'bussiness', 'takes,', 'york.we', 'probbably', 'dumbo!tips', 'consequence,', 'eveniing', 'wrapped', 'facade', 'crab', "advance!it's", 'phillip', 'back.there', 'yet.', 'despises', 'sandwiches??', 'available,', 'bouncer!', 'examples', "stick.it's", 'excellent.small', 'options.', 'nephews', 'enquiry', 'passed,', 'here.', 'up.so', 'open.take', 'hi', 'etc.?', 'warm........', 'block)', 'promises,', 'days!!!!many', "finale'", 'design', 'disappointment.if', 'tht', '.....thats', '2mn', 'checked).', 'parade?', 'fun;', 'would', 'cheaper.6.', 'photographs.', '8pm)', 'untouched', 'restored,', 'squirm.', 'did.', 'hollywood??', 'personnages...', 'armegeddon,', '3rds', 'questionable.', 'beautifully,', 'needed.i', 'musee', 'good!!', 'chicken.', 'etc.the', 'budge', 'waliking', 'on.queues', 'norms', 'everything:', 'exit', 'separately).', 'unremarkable', 'madness...still', 'knowledge).', 'own.he', '20people' ...
#
# Vocabulary California: {'windows...', 'facts', 'lunchable', 'itself...instead', 'contiki', '20s)', ':park', 'relocate', 'freak.', 'friend', 'itself)', '3day', '4:25', 'mix.', '(any)', 'ized,', 'grateful', 'homes', '(spectacular', "lines.don't", 'ride.like', 'summary?', 'times;', 'taste.', 'breakfast,', 'average,', '!........', 'legal', '112', 'kate', 'jostled', 'smiling', 'coat', 'more.the', 'rudely,', 'helpful', 'friends?', 'souvneirs', 'takes!', 'originals.', 'picturesque,', 'combined.', 'crossed', 'sunset,', 'halloween!', '3...more', 'bunny', 'budget', '(nobody', 'tween,', 'sugared', 'complains', 'saver...', 'vehicle;', 'christmes', '1969,', 'disneyland..its', 'artwork.', 'discouraged.enjoyed', 'agesindiana', 'hotel.walking', 'merriest', 'cash).', 'park!', 'timers:*', 'following', 'is....well,', 'makers', 'blasters', 'vents', 'dine)', '75,', 'done.disliked', 'unloaded', 'chips?', 'attractions.1.', 'drink:', '(10am)', 'prediction.', 'execption', 'between.2.', 'yesterdayland,', 'story!', 'later.we', 'hilton.', 'capistrano', 'momsone', 'youtu.be', 'cappuccino,', 'tumble', 'reasons,', '1030', 'interresting.', 'absorbed', 'this....if', 'see)', 'bored', 'dennis', 'passersby', 'practical', 'dvds', 'you!5.', 'secretive', 'magic.....', 'december!', 'cafes', 'noise.', 'spirit.i', 'disneyland!!!', 'checked)', 'factor,', 'waterwork', 'world,you', 'misery', 'because...', "person's", 'time.christmas', 'transform!', 'room),', 'wife,', 'available.now', '(weather', 'energy.10.', 'them!!this', 'attire,', 'college', 'feared.', 'hadonly', 'him.', 'disnneyland', 'glow.plan', 'pomagranate', 'angst', 'woods', 'out...warn', 'stated,', 'dismay', 'perfectly.the', 'circle.', 'benefit!', 'work,', 'steering', 'them,,', 'lunchtime...', 'dint', 'able...more', 'respected', 'steep.', 'discovered.', '10.wear', 'shaft', 'eating!', 'detours', 'fevers.', 'tips:try', 'nosquare.', 'opera', 'dancers.transport', 'it.disneyland', 'nhl', 'problem...again!', 'aerials,', 'oblivious,', 'detracts', "'pirate's", 'def', 'generic.', 'consume.', '9:55', '11:50', 'individually.', 'whatever....made', '(*apparently', 'genius.i', 'waisting', 'limit', 'trails.', 'sight,', 'watching.', 'visited),', "fun.there's", 'treat.of', 'situation.', 'mgr.', 'patch,', 'nook...so', 'treat,', 'sides,', 'saturday!!', 'goneinto', 'rough', 'grumps', 'off.lots', 'concentration', 'designs,', 'on..the', 'times...every', 'linings,', 'noise)', 'fav', 'mask,', 'pants,', 'parkside', 'arms,', 'duringbuzz', 'periods(spring', '(touch', 'injustice', 'consequence,', 'wrapped', 'and.....', 'facade', 'crab', 'mean.pick', "'bippity", 'laughs!', 'marriot.', 'yet.', 'lard', 'available,', 'examples', 'ig', 'starbucks.', 'options.', 'nephews', 'broads', 'passed,', 'here.', 'ball...', 'rekindled', 'majy', 'hi', 'varity.', 'adventureland...dole', "'one", 'resplendent', 'royalty.', 'westminster', 'toads)', 'boring...', 'design', 'tht', 'parade?', 'fun;', 'papas,', 'would', 'careworn', '8pm)', 'untouched', 'it.living', 'did.', '3rds', 'problematic.', 'beautifully,', 'questionable.', 'good!!', 'rides,even', 'chicken.', 'etc.the', 'budge', 'ak', 'jokes,', 'exit', 'byte', 'everything:', '5pm.want', 'size!!', '(youngest', 'repleat', 'chaperoning', 'appeared....it', 'twice!)', 'again...young', 'weapons,', 'mansiontips:get', 'waters,', 'dats', 'yes...even', '70.00', 'imagineers', 'year..', 'central', 'parks.ride', 'idisney', 'disappoint', 'giggling.we', 'oriental', 'security)', 'again...as', 'rides.by', 'restaurnat', 'maters', 'you.need', 'exuded', 'punitive.', 'crowds.one', 'equipment!food', '$2.99plus', 'course.if', 'chaos).', 'good.even', 'tosave', 'hats,', 'it!!disney', 'unsanitary.', 'breakfast;', 'meekly', 'program', 'camp;', 'disneyfan', 'money....basically', 'closed.if', 'shuttlestops', 'use', '($4', '8:30pm', 'space!!)', 'well.congratulations', 'learn)small', 'kindergardeners.', 'life.', '(been', "tokyo's", 'www.disneytouristblog.com', 'heartening.', 'kiwis', ':)this', 'tokyo.', 'spectaculars', 'street...overall', ' ...
